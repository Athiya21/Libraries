# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
iris = pd.read_csv(r'C:\Users\FATHIMA\Desktop\Datasceience_NareshIT\Feb\27th - Project\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.drop('Id',axis=1,inplace = True)

# %%
iris.head(1)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
sns.countplot('Species',data = iris)
plt.show()

# %%
plt.countplot('Species',data = iris)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-5325e7582f76> in <module>
# ----> 1 plt.countplot('Species',data = iris)
#       2 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'countplot'

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# - Jointplot

# %%
fig = sns.jointplot(x = 'SepalLengthCm', y = 'SepalWidthCm', data = iris)

# %%
sns.jointplot("SepalLengthCm","SepalWidthCm",data = iris, kind = reg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a3251c546db3> in <module>
# ----> 1 sns.jointplot("SepalLengthCm","SepalWidthCm",data = iris, kind = reg)
#
# NameError: name 'reg' is not defined

# %%
sns.jointplot("SepalLengthCm","SepalWidthCm",data = iris, kind = "reg")

# %%
sns.jointplot("SepalLengthCm","SepalWidthCm",data = iris, kind = "hex")

# %% [markdown]
# - Facet Grid plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sns.FacetGrid(iris, hue = 'Species',size = 5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %% [markdown]
# - Boxplot (or) whisker plot

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x = 'Species', y = 'PetalLengthCm', data = iris, order = ['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth = 2.5, orient ='v', dodge = False)

# %%
iris.boxplot(by="Species",figsize = (12,6))
# Out:
# array([[<AxesSubplot:title={'center':'PetalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'PetalWidthCm'}, xlabel='[Species]'>],
#        [<AxesSubplot:title={'center':'SepalLengthCm'}, xlabel='[Species]'>,
#         <AxesSubplot:title={'center':'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# - Strip plot

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.stripplot(x = 'Species', y = 'SepalLengthCm', data = iris, jitter = True, edgecolor = 'gray', size = 8, palette = 'winter', orient = 'v')

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x = "Species", y = "SepalLengthCm", data = iris)
fig = sns.stripplot(x = "Species", y = "SepalLengthCm", data = iris, jitter = True, edgecolor = "gray")

# %%
iris.head(1)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa

# %%
ax = sns.boxplot(x = "Species", y = "PetalLengthCm", data = iris)
ax = sns.stripplot(x = "Species", y = "PetalLengthCm", data = iris, jitter = True, edgecolor = "gray")

boxtwo = ax.artists[2]          # visually iris-virginica
boxtwo.set_facecolor('yellow') 
boxtwo.set_edgecolor('black')

boxthree = ax.artists[1]        # visually iris-versicolor
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')

boxfour = ax.artists[0]        # visually iris-setosa
boxfour.set_facecolor('green')
boxfour.set_edgecolor('black')

plt.show()

# %% [markdown]
# - violin plot

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(x = "Species", y = "SepalLengthCm", data = iris)

# %%
plt.figure(figsize = (15,10))

plt.subplot(2,2,1)
sns.violinplot(x = "Species", y = "PetalLengthCm", data = iris)

plt.subplot(2,2,2)
sns.violinplot(x = "Species", y = "PetalWidthCm", data = iris)

plt.subplot(2,2,3)
sns.violinplot(x = "Species", y = "SepalLengthCm", data = iris)

plt.subplot(2,2,4)
sns.violinplot(x = "Species", y = "SepalWidthCm", data = iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# - Pair plot

# %%
sns.pairplot(data = iris, kind = "scatter")

# %%
sns.pairplot(iris, hue = "Species")

# %% [markdown]
# - Heat Map

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(iris.corr(),annot = True,cmap = 'cubehelix', linewidths = 1, linecolor = 'k', square = True, mask = False, vmin = -1, vmax = 1, cbar_kws = {"orientation" : "vertical"}, cbar = True)

# %% [markdown]
# - Distribution plot

# %%
iris.hist(edgecolor = 'black', linewidth = 1.2)
fig = plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# - Swarm plot

# %%
sns.set(style = "darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(x = "Species", y = "PetalLengthCm", data = iris)

# %%
sns.set(style = "whitegrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x = "Species", y  = "PetalLengthCm", data = iris, inner = None)
ax = sns.swarmplot(x = "Species", y = "PetalLengthCm", data = iris, color = "White", edgecolor = "black")

# %% [markdown]
# - LM Plot

# %%
fig = sns.lmplot(x = "PetalLengthCm", y = "PetalWidthCm", data = iris)

# %% [markdown]
# - Facet Grid

# %%
sns.FacetGrid(iris, hue = "Species", size = 6).map(sns.kdeplot, "PetalLengthCm").add_legend()
plt.ioff()

# %% [markdown]
# - Factor plot

# %%
sns.factorplot('Species', 'SepalLengthCm', data = iris)
plt.ioff()
plt.show()

# %% [markdown]
# - Box plot

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(x = "Species", y = "SepalLengthCm", data = iris)

# %% [markdown]
# - KDE plot

# %%
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.
sub=iris[iris['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']],cmap="plasma", shade=True, shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-04d96741623d> in <module>
#       1 # Create a kde plot of sepal_length versus sepal width for setosa species of flower.
#       2 sub=iris[iris['Species']=='Iris-setosa']
# ----> 3 sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']],cmap="plasma", shade=True, shade_lowest=False)
#       4 plt.title('Iris-setosa')
#       5 plt.xlabel('Sepal Length Cm')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, **kwargs)
#    1728             plot_kws["color"] = color
#    1729
# -> 1730         p.plot_univariate_density(
#    1731             multiple=multiple,
#    1732             common_norm=common_norm,
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in plot_univariate_density(self, multiple, common_norm, common_grid, fill, legend, estimate_kws, **plot_kws)
#    1028
#    1029             ax_obj = self.ax if self.ax is not None else self.facets
# -> 1030             self._add_legend(
#    1031                 ax_obj, artist, fill, False, multiple, alpha, plot_kws, {},
#    1032             )
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _add_legend(self, ax_obj, artist, fill, element, multiple, alpha, artist_kws, legend_kws)
#     141         for level in self._hue_map.levels:
#     142             color = self._hue_map(level)
# --> 143             handles.append(artist(
#     144                 **self._artist_kws(
#     145                     artist_kws, fill, element, multiple, color, alpha
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Patch' object has no property 'cmap'

# %%
print(sns.__version__)
# Out:
# 0.11.0

# %%
sub=iris[iris['Species']=='Iris-setosa']
sns.kdeplot(
    x=sub['SepalLengthCm'],
    y=sub['SepalWidthCm'],
    cmap="plasma",
    shade=True,  # valid in v0.11.0
    shade_lowest = False,
    thresh=0.05  # density threshold (optional)
)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
# Out:
# Text(0, 0.5, 'Sepal Width Cm')

# %% [markdown]
# - Dashboard

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize = (15,15))
k1 = sns.boxplot(x = "Species", y = "PetalLengthCm", data = iris, ax = axes[0,0])
k2 = sns.violinplot(x = "Species", y = "PetalLengthCm", data = iris, ax = axes[0,1])
k3 = sns.stripplot(x = "Species", y = "SepalLengthCm", data = iris, jitter = True, edgecolor = 'gray', size = 8, palette = 'winter', orient = 'v', ax = axes[1,0])
axes[1,1].hist(iris.PetalLengthCm, bins = 100)
plt.show()

# %%
iris['Species'] = iris['Species'].astype('category')

# %% [markdown]
# - Stacked Histogram

# %%
list1=list()
mylabels=list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# - Area Plot

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Dist Plot

# %%
sns.distplot(iris['SepalLengthCm'],kde=True,bins=20)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>
